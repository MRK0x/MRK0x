# %% [markdown]
# <a href="https://colab.research.google.com/github/MRK0x/MRK0x/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1069, done.
# remote: Counting objects: 100% (1069/1069), done.
# remote: Compressing objects: 100% (889/889), done.
# remote: Total 1069 (delta 180), reused 667 (delta 160), pack-reused 0 (from 0)
# Receiving objects: 100% (1069/1069), 31.29 MiB | 20.62 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  upgrading npm...
#   node           v20.19.0 | npm 11.12.1
#                  installing bun...
#                  bun installed (1.3.12)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [====================] 13/13  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b8746
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-04-10 21:30:59 [info     ] 🦥 Starting Unsloth Studio...
# 2026-04-10 21:30:59 [info     ]    Loading backend...
# 2026-04-10 21:30:59 [info     ]    Starting server...
# INFO:     Started server process [3833]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CUDA -- Tesla T4
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-04-10T21:31:10.373945Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-10T21:31:12.324763Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-usw4b0-2iausnrg8sav5-b.us-west4-0.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-04-10T21:31:15.876724Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 11.83}
# {"timestamp": "2026-04-10T21:31:17.790119Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.27}
# {"timestamp": "2026-04-10T21:31:18.036713Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 5.61}
# {"timestamp": "2026-04-10T21:31:18.081824Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 8.45}
# {"timestamp": "2026-04-10T21:31:18.460065Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 22.3}
# {"timestamp": "2026-04-10T21:31:19.521772Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 11.96}
# {"timestamp": "2026-04-10T21:31:19.730614Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.75}
# {"timestamp": "2026-04-10T21:31:20.039466Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 8.28}
# {"timestamp": "2026-04-10T21:31:20.350129Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 14.23}
# {"timestamp": "2026-04-10T21:31:21.425225Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-04-10T21:31:25.423007Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-04-10T21:31:26.608578Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 130.24}
# {"timestamp": "2026-04-10T21:31:27.040200Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 151.08}
# {"timestamp": "2026-04-10T21:31:27.317213Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.31}
# {"timestamp": "2026-04-10T21:31:27.578430Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.61}
# {"timestamp": "2026-04-10T21:31:27.843101Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.98}
# {"timestamp": "2026-04-10T21:31:28.108087Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.14}
# {"timestamp": "2026-04-10T21:32:11.139769Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.21}
# {"timestamp": "2026-04-10T21:32:14.659860Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/studio", "status_code": 200, "process_time_ms": 1.3}
# {"timestamp": "2026-04-10T21:32:15.536503Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.65}
# {"timestamp": "2026-04-10T21:32:15.806577Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.83}
# {"timestamp": "2026-04-10T21:32:17.182547Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-04-10T21:32:17.194153Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 15.97}
# {"timestamp": "2026-04-10T21:32:17.474040Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-04-10T21:32:40.314395Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E4B-it"}
# {"timestamp": "2026-04-10T21:32:40.322984Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E4B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-10T21:32:40.331068Z", "level": "info", "event": "Model 'unsloth/gemma-4-E4B-it' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-10T21:32:59.277870Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/gemma-4-E4B-it': model_type=gemma4, architectures=['Gemma4ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-10T21:33:02.698308Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E4B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-04-10T21:33:02.790485Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E4B-it", "status_code": 200, "process_time_ms": 22478.75}
# {"timestamp": "2026-04-10T21:33:08.341740Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 2.8}
# {"timestamp": "2026-04-10T21:33:09.236281Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.71}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3833/3552804093.py in <cell line: 0>()
#       1 from google.colab import output
#       2 output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
# ----> 3 for _ in range(10000): time.sleep(300), print("=", end = "")
#
# KeyboardInterrupt:

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
